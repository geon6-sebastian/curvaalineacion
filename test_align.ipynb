# %%
import shapefile as shp
import geopandas as gpd
import numpy as np
import curvas

curvas.MAXSTEPRK45_ANG = curvas.DEG2RAD(0.1)

elli = curvas.pelipsoide_init(curvas.GRS80_f, curvas.GRS80_a)
plat = curvas.init_platn6(elli.n)

fils = []

for phi1d in [10]:
    for L1d in [0]:
        for phi2d in [10, 30, 50, -10, -30, -50]:
            for L2d in [20, 40, 60, 80]:
                fila = []
                fila.append([phi1d, L1d, phi2d, L2d])
                phi1 = curvas.DEG2RAD(phi1d)
                phi2 = curvas.DEG2RAD(phi2d)
                L1 = curvas.DEG2RAD(L1d)
                L2 = curvas.DEG2RAD(L2d)
                L11 = L1
                L22 = L2
                alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_align_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
                fila.append([curvas.RAD2DEG(alpha),dist,area,curvas.RAD2DEG(Phi0),curvas.RAD2DEG(L0)])
                
                alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_normal_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
                fila.append([curvas.RAD2DEG(alpha),dist,area,curvas.RAD2DEG(Phi0),curvas.RAD2DEG(L0)])
                
                alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_central_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
                fila.append([curvas.RAD2DEG(alpha),dist,area,curvas.RAD2DEG(Phi0),curvas.RAD2DEG(L0)])
                
                fils.append(fila)

import csv

with open('resultados.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    # Opcional: escribir cabecera
    cabecera = ['phi1_orig', 'L1_orig', 'phi2_orig', 'L2_orig',
                'alpha_RK45', 'dist_RK45', 'area_RK45', 'Phi0_RK45', 'L0_RK45',
                'alpha_nsect', 'dist_nsect', 'area_nsect', 'Phi0_nsect', 'L0_nsect',
                'alpha_csect', 'dist_csect', 'area_csect', 'Phi0_csect', 'L0_csect']
    writer.writerow(cabecera)
    
    for fila in fils:
        # fila es una lista de 4 elementos (el primero es lista de 4, luego tres listas de 5)
        fila_plana = []
        for elemento in fila:
            # cada 'elemento' es una lista (de 4 o 5 números)
            fila_plana.extend(elemento)   # los añade como valores individuales
        writer.writerow(fila_plana)

for phi1d in [10]:
    for L1d in [0]:
        for phi2d in [10, 30, 50, -10]:
            for L2d in [-20, -40, -60, -80]:
                fila = []
                fila.append([phi1d, L1d, phi2d, L2d])
                phi1 = curvas.DEG2RAD(phi1d)
                phi2 = curvas.DEG2RAD(phi2d)
                L1 = curvas.DEG2RAD(L1d)
                L2 = curvas.DEG2RAD(L2d)
                L11 = L1
                L22 = L2
                alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_align_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
                fila.append([curvas.RAD2DEG(alpha),dist,area,curvas.RAD2DEG(Phi0),curvas.RAD2DEG(L0)])
                
                alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_normal_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
                fila.append([curvas.RAD2DEG(alpha),dist,area,curvas.RAD2DEG(Phi0),curvas.RAD2DEG(L0)])
                
                alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_central_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
                fila.append([curvas.RAD2DEG(alpha), dist,area,curvas.RAD2DEG(Phi0),curvas.RAD2DEG(L0)])
                
                fils.append(fila)

with open('resultados_neq.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    # Opcional: escribir cabecera
    cabecera = ['phi1_orig', 'L1_orig', 'phi2_orig', 'L2_orig',
                'alpha_RK45', 'dist_RK45', 'area_RK45', 'Phi0_RK45', 'L0_RK45',
                'alpha_nsect', 'dist_nsect', 'area_nsect', 'Phi0_nsect', 'L0_nsect',
                'alpha_csect', 'dist_csect', 'area_csect', 'Phi0_csect', 'L0_csect']
    writer.writerow(cabecera)
    
    for fila in fils:
        # fila es una lista de 4 elementos (el primero es lista de 4, luego tres listas de 5)
        fila_plana = []
        for elemento in fila:
            # cada 'elemento' es una lista (de 4 o 5 números)
            fila_plana.extend(elemento)   # los añade como valores individuales
        writer.writerow(fila_plana)

# %%
# Ejemplo considerando puntos cerca de las antípodas

import curvas
import numpy as np
import math

elli = curvas.pelipsoide_init(curvas.GRS80_f, curvas.GRS80_a)
plat = curvas.init_platn6(elli.n)

#estos valores son tomados de la curva de alineacion Ejemplo1
phi1 = curvas.DEG2RAD(-38.5169945511);  L1 = curvas.DEG2RAD(43.3527226507)
phi2 = curvas.DEG2RAD(38.5169048486);  L2 = curvas.DEG2RAD(135.4700645484)
phi1 = curvas.DEG2RAD(-30.00); L1 = curvas.DEG2RAD(0.0)
phi2 = curvas.DEG2RAD(30.0);   L2 = curvas.DEG2RAD(179.0)

#L1, L2 = L2, L1

L11 = L1
L22 = L2

alpha, dist, Phi0, L0, pathpoints = curvas.inv_align_dist(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos.csv", pathpoints, delimiter=",", fmt='%.15f')
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_dist.shp")

alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_align_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Area total: {area:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_area.csv", pathpoints, delimiter=",", fmt='%.15f')
curvas.guardar_curva_kmz(pathpoints, "puntos_area.kmz")
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_area.shp")

alpha, dist, Phi0, L0, pathpoints = curvas.inv_normal_dist(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_sect.csv", pathpoints, delimiter=",", fmt='%.15f')

alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_normal_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Area total: {area:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_area_sect.csv", pathpoints, delimiter=",", fmt='%.15f')
curvas.guardar_curva_kmz(pathpoints, "puntos_area_sect.kmz")
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_area_sect.shp")

alpha, dist, Phi0, L0, pathpoints = curvas.inv_central_dist(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_centralsect.csv", pathpoints, delimiter=",", fmt='%.15f')

alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_central_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Area total: {area:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_area_centralsect.csv", pathpoints, delimiter=",", fmt='%.15f')
curvas.guardar_curva_kmz(pathpoints, "puntos_area_centralsect.kmz")
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_area_centralsect.shp")

import pandas as pd

beta1 = curvas.phi2beta(elli, phi1)
beta2 = curvas.phi2beta(elli, phi2)
cs = curvas.cs_align_(elli, beta1, L1, beta2, L2)

df = pd.read_csv("puntos_area.csv")
lambdas = df.iloc[:, 1]
phis_aprox = df.iloc[:, 0]
phis = []
error = []

cant = len(lambdas)

for i in range(0, cant):
    print(lambdas[i])
    beta_aprox = curvas.phi2beta(elli,  curvas.DEG2RAD(phis_aprox[i]))
    beta =  curvas.L2beta_align(elli, cs, beta_aprox,  curvas.DEG2RAD(lambdas[i]))
    phi =  curvas.beta2phi(elli, beta)
    phis.append( curvas.RAD2DEG(phi))
    error.append((curvas.DEG2RAD(phis_aprox[i]) - phi)*elli.a)
  
columna1 = [float(x) for x in phis_aprox]
columna2 = [float(x) for x in lambdas]
columna3 = [float(x) for x in phis]
columna4 = [float(x) for x in error]
columna5 = [math.fabs(float(x)) for x in error]

df = pd.DataFrame({
    'phi_aprox': columna1,
    'lambda': columna2,
    'phi': columna3,
    'error': columna4,
    'error_abs': columna5
})

# Guardar en un archivo CSV
df.to_csv("Error_posicion_179.csv", index=False,  float_format="%.15f")
print(np.max(columna5))
# Out:
# alfa: 110.767516948 deg
# Distancia total: 21656598.9243 m
# Puntos calculados: 2384
# phi2: 30.000000000
# L2: 179.000000000
# PHI0: 38.517007702
# L0: 135.600578056
# ---------------------------------------------------
# alfa: 110.767516948 deg
# Distancia total: 21656598.9243 m
# Area total: 1.9207 m
# Puntos calculados: 2384
# phi2: 30.000000000
# L2: 179.000000000
# PHI0: 38.517007702
# L0: 135.600578056
# ---------------------------------------------------
# alfa: 110.767516948 deg
# Distancia total: 19935824.0794 m
# Puntos calculados: 1793
# phi2: 30.000000000
# L2: 179.000000000
# PHI0: -35.954919920
# L0: 37.177826494
# ---------------------------------------------------
# alfa: 110.767516948 deg
# Distancia total: 19935824.0794 m
# Area total: -29477826460235.5664 m
# Puntos calculados: 1793
# phi2: 30.000000000
# L2: 179.000000000
# PHI0: -35.954919920
# L0: 37.177826494
# ---------------------------------------------------
# alfa: 89.751252549 deg
# ...

# %%
# Ejemplo considerando 2 puntos anteriores

import curvas
import numpy as np

elli = curvas.pelipsoide_init(curvas.GRS80_f, curvas.GRS80_a)
plat = curvas.init_platn6(elli.n)

#estos valores son tomados de la curva de alineacion Ejemplo1
phi1 = curvas.DEG2RAD(-38.5169945511);  L1 = curvas.DEG2RAD(43.3527226507)
phi2 = curvas.DEG2RAD(38.5169048486);  L2 = curvas.DEG2RAD(135.4700645484)
#phi1 = curvas.DEG2RAD(-30.00); L1 = curvas.DEG2RAD(0.0)
#phi2 = curvas.DEG2RAD(30.0);   L2 = curvas.DEG2RAD(179.0)

L11 = 0.0
L22 = curvas.DEG2RAD(179.0)

alpha, dist, Phi0, L0, pathpoints = curvas.inv_align_dist(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos.csv", pathpoints, delimiter=",", fmt='%.10f')
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_dist.shp")

alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_align_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Area total: {area:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_area.csv", pathpoints, delimiter=",", fmt='%.10f')
curvas.guardar_curva_kmz(pathpoints, "puntos_area.kmz")
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_area.shp")

alpha, dist, Phi0, L0, pathpoints = curvas.inv_normal_dist(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_sect.csv", pathpoints, delimiter=",", fmt='%.10f')

alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_normal_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Area total: {area:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_area_sect.csv", pathpoints, delimiter=",", fmt='%.10f')
curvas.guardar_curva_kmz(pathpoints, "puntos_area_sect.kmz")
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_area_sect.shp")

alpha, dist, Phi0, L0, pathpoints = curvas.inv_central_dist(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_centralsect.csv", pathpoints, delimiter=",", fmt='%.10f')

alpha, dist, area, Phi0, L0, pathpoints = curvas.inv_central_area_ex(plat, elli, phi1, L1, phi2, L2, L11, L22)
cant_points, dummy = pathpoints.shape
print(f"alfa: {curvas.RAD2DEG(alpha):.9f} deg")
print(f"Distancia total: {dist:.4f} m")
print(f"Area total: {area:.4f} m")
print(f"Puntos calculados: {cant_points}")
print(f"phi2: {pathpoints[cant_points-1, 0]:.9f}")
print(f"L2: {pathpoints[cant_points-1, 1]:.9f}")
print(f"PHI0: {curvas.RAD2DEG(Phi0):.9f}")
print(f"L0: {curvas.RAD2DEG(L0):.9f}")
print(f"---------------------------------------------------")
np.savetxt("puntos_area_centralsect.csv", pathpoints, delimiter=",", fmt='%.10f')
curvas.guardar_curva_kmz(pathpoints, "puntos_area_centralsect.kmz")
curvas.guardar_como_linea_shapefile(pathpoints, "puntos_area_centralsect.shp")
# Out:
# alfa: 89.917023180 deg
# Distancia total: 19944181.9357 m
# Puntos calculados: 1796
# phi2: 47.674475908
# L2: 179.000000000
# PHI0: 47.674493955
# L0: 178.935548639
# ---------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\data\Catedras-UNL\Geodesia\informes\curva_alineacion\programas\python\test_align.ipynb Cell 3 line 3
#      <a href='vscode-notebook-cell:/d%3A/data/Catedras-UNL/Geodesia/informes/curva_alineacion/programas/python/test_align.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a> np.savetxt("puntos.csv", pathpoints, delimiter=",", fmt='%.10f')
#      <a href='vscode-notebook-cell:/d%3A/data/Catedras-UNL/Geodesia/informes/curva_alineacion/programas/python/test_align.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a> curvas.guardar_como_linea_shapefile(pathpoints, "puntos_dist.shp")
# ...

# %%
# Ejemplo considerando 2 puntos anteriores

import curvas
import numpy as np

elli = curvas.pelipsoide_init(curvas.GRS80_f, curvas.GRS80_a)
plat = curvas.init_platn6(elli.n)

curvas.MAXSTEPRK45_ANG = curvas.DEG2RAD(0.1)

#estos valores son tomados de la curva de alineacion Ejemplo1
phi1 = curvas.DEG2RAD(-38.5169945511);  L1 = curvas.DEG2RAD(43.3527226507)
phi2 = curvas.DEG2RAD(38.5169048486);  L2 = curvas.DEG2RAD(135.4700645484)
#phi1 = curvas.DEG2RAD(-30.00); L1 = curvas.DEG2RAD(0.0)
#phi2 = curvas.DEG2RAD(30.0);   L2 = curvas.DEG2RAD(179.0)

#L11 = 0.0; L22 = curvas.DEG2RAD(179.0)
L11 = L1; L22 = L2

alpha, dist, Phi0, L0, pathpoints = curvas.inv_align_dist(plat, elli, phi1, L1, phi2, L2, L11, L22)

print(plat.PARA2AUTH[1:3])

phi2, L2 = curvas.direct_curva_align_(plat, elli, phi1, L1, alpha, dist)
print(plat.PARA2AUTH[1:3])
